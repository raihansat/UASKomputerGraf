# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import seaborn as sns
import matplotlib.dates as dts

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-02d02fad-b442-4ddd-acf3-b244d679ed31" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02d02fad-b442-4ddd-acf3-b244d679ed31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv("Dataset UAS.csv")
dataset.head(15)
# Out:
#     Bulan  1981-1990  1991-2000  2001-2010
# 0       1        489        482        422
# 1       2        308        420        410
# 2       3        299        420        378
# 3       4        260        340        283
# 4       5        199        140        125
# 5       6        147        128        105
# 6       7         40         59         50
# 7       8         70         60          2
# 8       9        135         60         60
# 9      10        230        402        338
# 10     11        420        498        640
# 11     12        400        405        425

# %%
plt.figure(figsize=(12, 6))

x = np.arange(len(dataset['Bulan']))
width = 0.2
colors = ['tomato', 'violet', 'yellow']

for i, stasiun in enumerate(dataset.keys()):
    if stasiun != 'Bulan':
        plt.bar(x + (i * width), dataset[stasiun], width=width, label=stasiun, color=colors[i % len(colors)])

plt.xlabel('Bulan')
plt.ylabel('Curah Hujan (mm)')


plt.xticks(x)
plt.legend(loc="upper center")
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-68e017b2-854b-481e-b05c-c57bf2359fed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68e017b2-854b-481e-b05c-c57bf2359fed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("sh.csv")
data.head(15)
# Out:
#    jam (utc)  asimilasi  observasi  non Asimilasi
# 0        0.0         23         25             25
# 1        3.0         24         22             22
# 2        6.0         23         22             24
# 3        9.0         24         23             25
# 4       12.0         28         25             24
# 5       15.0         24         22             28
# 6       18.0         24         23             25
# 7       21.0         23         23             24

# %%
df = pd.DataFrame(data)
df_melt = pd.melt(df, id_vars='jam (utc)', var_name='Kategori', value_name='Jumlah')

plt.figure(figsize=(10, 4))
sns.lineplot(data=df_melt, x='jam (utc)', y='Jumlah', hue='Kategori', palette={'asimilasi': 'tomato', 'observasi': 'violet', 'non Asimilasi': 'yellow'}, linewidth=3, markers=True, marker='o')

plt.xlabel('Jam (UTC)')
plt.ylabel('Celcius')


plt.legend()
plt.show()
